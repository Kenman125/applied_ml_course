# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, confusion_matrix, RocCurveDisplay
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('lecture_03_data.csv',
                names = ['age',
                         'workclass',
                         'fnlwgt',
                         'education',
                         'education-num',
                         'marital-status',
                         'occupation',
                         'relationship',
                         'race',
                         'sex',
                         'capital-gain',
                         'capital-loss',
                         'hours-per-week',
                         'native-country',
                         'income'])

# %%
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# 5      Married-civ-spouse     Exec-managerial            Wife   White
# 6   Married-spouse-absent       Other-service   Not-in-family   Black
# 7      Married-civ-spouse     Exec-managerial         Husband   White
# 8           Never-married      Prof-specialty   Not-in-family   White
# 9      Married-civ-spouse     Exec-managerial         Husband   White
#
#        sex  capital-gain  capital-loss  hours-per-week  native-country  income
# 0     Male          2174             0              40   United-States   <=50K
# 1     Male             0             0              13   United-States   <=50K
# 2     Male             0             0              40   United-States   <=50K
# 3     Male             0             0              40   United-States   <=50K
# 4   Female             0             0              40            Cuba   <=50K
# 5   Female             0             0              40   United-States   <=50K
# 6   Female             0             0              16         Jamaica   <=50K
# 7     Male             0             0              45   United-States    >50K
# 8   Female         14084             0              50   United-States    >50K
# 9     Male          5178             0              40   United-States    >50K

# %%
num_vars = ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
cat_vars = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']
target = 'income'

# %%
# Let's make our train-test split

# %%
X = df[num_vars + cat_vars]
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %%
# Check for missing data:

# %%
y_train
# Out:
# 31674      >50K
# 19303     <=50K
# 5535      <=50K
# 8693      <=50K
# 14777     <=50K
#           ...
# 22401     <=50K
# 17093     <=50K
# 27063     <=50K
# 8366       >50K
# 17530     <=50K
# Name: income, Length: 26048, dtype: object

# %%
for col_name in X_train.columns:
    print('Column ', col_name, ' has: ', X_train[col_name].isna().sum(), ' missing values.')
# Out:
# Column  age  has:  0  missing values.
# Column  fnlwgt  has:  0  missing values.
# Column  education-num  has:  0  missing values.
# Column  capital-gain  has:  0  missing values.
# Column  capital-loss  has:  0  missing values.
# Column  hours-per-week  has:  0  missing values.
# Column  workclass  has:  0  missing values.
# Column  education  has:  0  missing values.
# Column  marital-status  has:  0  missing values.
# Column  occupation  has:  0  missing values.
# Column  relationship  has:  0  missing values.
# Column  race  has:  0  missing values.
# Column  sex  has:  0  missing values.
# Column  native-country  has:  0  missing values.

# %% [markdown]
# Hooray! No missing data :)

# %%
# Explore categorical data:

# %%
for cat_col_name in cat_vars:
    print(X_train[cat_col_name].value_counts())
# Out:
#  Private             18158
#  Self-emp-not-inc     2032
#  Local-gov            1682
#  ?                    1462
#  State-gov            1034
#  Self-emp-inc          891
#  Federal-gov           770
#  Without-pay            13
#  Never-worked            6
# Name: workclass, dtype: int64
#  HS-grad         8436
#  Some-college    5851
#  Bachelors       4249
#  Masters         1370
#  Assoc-voc       1104
#  11th             959
#  Assoc-acdm       861
#  10th             740
#  7th-8th          505
#  Prof-school      436
#  9th              399
#  12th             355
#  Doctorate        345
#  5th-6th          257
#  1st-4th          137
#  Preschool         44
# Name: education, dtype: int64
#  Married-civ-spouse       11958
#  Never-married             8527
#  Divorced                  3589
#  Separated                  820
#  Widowed                    799
#  Married-spouse-absent      333
#  Married-AF-spouse           22
# Name: marital-status, dtype: int64
#  Craft-repair         3284
#  Prof-specialty       3279
#  Exec-managerial      3229
#  Adm-clerical         3008
#  Sales                2940
#  Other-service        2599
#  Machine-op-inspct    1604
#  ?                    1468
#  Transport-moving     1307
#  Handlers-cleaners    1105
#  Farming-fishing       803
#  Tech-support          767
#  Protective-serv       530
#  Priv-house-serv       117
#  Armed-Forces            8
# Name: occupation, dtype: int64
#  Husband           10514
#  Not-in-family      6641
#  Own-child          4019
#  Unmarried          2800
#  Wife               1278
#  Other-relative      796
# Name: relationship, dtype: int64
#  White                 22239
#  Black                  2500
#  Asian-Pac-Islander      844
#  Amer-Indian-Eskimo      254
#  Other                   211
# Name: race, dtype: int64
#  Male      17394
#  Female     8654
# Name: sex, dtype: int64
#  United-States                 23359
#  Mexico                          509
#  ?                               461
#  Philippines                     155
#  Germany                         107
#  Canada                           99
#  Puerto-Rico                      94
#  El-Salvador                      85
#  England                          80
#  Cuba                             76
#  India                            76
#  Jamaica                          66
#  South                            64
#  China                            62
#  Dominican-Republic               59
#  Vietnam                          58
#  Japan                            51
#  Italy                            51
#  Poland                           48
#  Guatemala                        47
#  Columbia                         46
#  Taiwan                           40
#  Haiti                            36
#  Portugal                         29
#  Iran                             28
#  Nicaragua                        26
#  Peru                             22
#  Ecuador                          21
#  France                           21
#  Greece                           21
#  Ireland                          20
#  Hong                             18
#  Cambodia                         16
#  Laos                             16
#  Thailand                         13
#  Trinadad&Tobago                  13
#  Yugoslavia                       12
#  Hungary                          12
#  Honduras                         12
#  Outlying-US(Guam-USVI-etc)       11
#  Scotland                          7
#  Holand-Netherlands                1
# Name: native-country, dtype: int64

# %% [markdown]
# The `native-country` column seems to present the biggest issue let's roll all countries other than United Statues into a single category 'Other'

# %%
X_train['native-country'] = pd.Series(['United-States' if x==' United-States' else 'Non-US' for x in X_train['native-country']])

# %%
X_train['native-country'].value_counts()
# Out:
# United-States    18634
# Non-US            2175
# Name: native-country, dtype: int64

# %% [markdown]
# ### Exercise:
# I replaced our original data with a new (and improved?) version. Where is the old data? Was this a good idea?

# %%
# Explore numeric data

# %%
X_train[num_vars].describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  26048.000000  2.604800e+04   26048.000000  26048.000000  26048.000000
# mean      38.593174  1.894822e+05      10.076935   1080.185504     89.173142
# std       13.653757  1.053041e+05       2.564347   7430.465076    407.216336
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.176740e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.779035e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.367048e+05      12.000000      0.000000      0.000000
# max       90.000000  1.366120e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    26048.000000
# mean        40.441454
# std         12.345814
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# A few interesting things here:
# 1. Age seems reasonable from a data quality perspective, and seems to scew young.
# 2. Who knows what fnlwgt means?
# 3. Education-num is interesting seemingly sparsely populated at the ends (especially the low end).
# 4. Capital gain is almost always 0 it seems, but with some very large values. It seems that some rounding has occurred (99999.0 seems like a ceiling). Maybe more natural as a binary.
# 5. Capital-loss is similar to capital gain but doesn't have the high values that look rounded.
# 6. Hours per week: A little bit odd, seems like there's some weird behavior where lots of people work 40-45 hours, and then you have some "part time" folks, and some people that work quite a bit more - probably capped at 99. Probably would benefit from breaking into a 3-level categorical.
#
# I won't deal with any of these, but feel free to explore on your own!

# %%
#Let's now one-hot-encode our categoricals
X_train_dummied = pd.get_dummies(X_train, columns=cat_vars)

# %%
X_train_dummied.transpose().head(100)
# Out:
#                                         31674   19303  5535    8693    14777  \
# age                                        51      31     25      45      27
# fnlwgt                                 289436  200246  49092  226246  267989
# education-num                              13       5     13       9      10
# capital-gain                                0       0      0       0       0
# capital-loss                                0       0      0       0       0
# hours-per-week                             60      40     40      50      40
# workclass_ ?                                0       0      0       0       0
# workclass_ Federal-gov                      0       0      0       0       0
# workclass_ Local-gov                        0       0      0       0       0
# workclass_ Never-worked                     0       0      0       0       0
# workclass_ Private                          1       1      1       1       1
# workclass_ Self-emp-inc                     0       0      0       0       0
# workclass_ Self-emp-not-inc                 0       0      0       0       0
# workclass_ State-gov                        0       0      0       0       0
# workclass_ Without-pay                      0       0      0       0       0
# education_ 10th                             0       0      0       0       0
# education_ 11th                             0       0      0       0       0
# education_ 12th                             0       0      0       0       0
# education_ 1st-4th                          0       0      0       0       0
# education_ 5th-6th                          0       0      0       0       0
# education_ 7th-8th                          0       0      0       0       0
# education_ 9th                              0       1      0       0       0
# education_ Assoc-acdm                       0       0      0       0       0
# education_ Assoc-voc                        0       0      0       0       0
# education_ Bachelors                        1       0      1       0       0
# education_ Doctorate                        0       0      0       0       0
# education_ HS-grad                          0       0      0       1       0
# education_ Masters                          0       0      0       0       0
# education_ Preschool                        0       0      0       0       0
# education_ Prof-school                      0       0      0       0       0
# education_ Some-college                     0       0      0       0       1
# marital-status_ Divorced                    0       0      0       1       0
# marital-status_ Married-AF-spouse           0       0      0       0       0
# marital-status_ Married-civ-spouse          1       0      0       0       1
# marital-status_ Married-spouse-absent       0       0      0       0       0
# marital-status_ Never-married               0       1      1       0       0
# marital-status_ Separated                   0       0      0       0       0
# marital-status_ Widowed                     0       0      0       0       0
# occupation_ ?                               0       0      0       0       0
# occupation_ Adm-clerical                    0       0      0       0       0
# occupation_ Armed-Forces                    0       0      0       0       0
# occupation_ Craft-repair                    0       0      0       0       0
# occupation_ Exec-managerial                 1       0      0       0       0
# occupation_ Farming-fishing                 0       0      0       0       0
# occupation_ Handlers-cleaners               0       0      0       1       0
# occupation_ Machine-op-inspct               0       0      0       0       1
# occupation_ Other-service                   0       1      1       0       0
# occupation_ Priv-house-serv                 0       0      0       0       0
# occupation_ Prof-specialty                  0       0      0       0       0
# occupation_ Protective-serv                 0       0      0       0       0
# occupation_ Sales                           0       0      0       0       0
# occupation_ Tech-support                    0       0      0       0       0
# occupation_ Transport-moving                0       0      0       0       0
# relationship_ Husband                       1       0      0       0       1
# relationship_ Not-in-family                 0       0      0       1       0
# relationship_ Other-relative                0       0      0       0       0
# relationship_ Own-child                     0       1      1       0       0
# relationship_ Unmarried                     0       0      0       0       0
# relationship_ Wife                          0       0      0       0       0
# race_ Amer-Indian-Eskimo                    0       0      0       0       0
# race_ Asian-Pac-Islander                    0       0      0       0       0
# race_ Black                                 0       0      0       0       0
# race_ Other                                 0       0      0       0       0
# race_ White                                 1       1      1       1       1
# sex_ Female                                 0       0      0       0       0
# sex_ Male                                   1       1      1       1       1
# native-country_Non-US                       0       0      1       0       0
# native-country_United-States                0       1      0       1       1
#
#                                         27748   6020    15961   5195    31949  \
# age                                        40      57      47      43      47
# fnlwgt                                 252392  190554  198660  115603  197038
# education-num                               3       6      13      10      13
# capital-gain                                0       0       0       0       0
# capital-loss                                0       0       0       0       0
# hours-per-week                             40      60      40      40      50
# workclass_ ?                                0       0       0       0       0
# workclass_ Federal-gov                      0       0       0       0       1
# workclass_ Local-gov                        0       0       1       1       0
# workclass_ Never-worked                     0       0       0       0       0
# workclass_ Private                          1       0       0       0       0
# workclass_ Self-emp-inc                     0       0       0       0       0
# workclass_ Self-emp-not-inc                 0       1       0       0       0
# workclass_ State-gov                        0       0       0       0       0
# workclass_ Without-pay                      0       0       0       0       0
# education_ 10th                             0       1       0       0       0
# education_ 11th                             0       0       0       0       0
# education_ 12th                             0       0       0       0       0
# education_ 1st-4th                          0       0       0       0       0
# education_ 5th-6th                          1       0       0       0       0
# education_ 7th-8th                          0       0       0       0       0
# education_ 9th                              0       0       0       0       0
# education_ Assoc-acdm                       0       0       0       0       0
# education_ Assoc-voc                        0       0       0       0       0
# education_ Bachelors                        0       0       1       0       1
# education_ Doctorate                        0       0       0       0       0
# education_ HS-grad                          0       0       0       0       0
# education_ Masters                          0       0       0       0       0
# education_ Preschool                        0       0       0       0       0
# education_ Prof-school                      0       0       0       0       0
# education_ Some-college                     0       0       0       1       0
# marital-status_ Divorced                    0       1       0       1       0
# marital-status_ Married-AF-spouse           0       0       0       0       0
# marital-status_ Married-civ-spouse          1       0       1       0       1
# marital-status_ Married-spouse-absent       0       0       0       0       0
# marital-status_ Never-married               0       0       0       0       0
# marital-status_ Separated                   0       0       0       0       0
# marital-status_ Widowed                     0       0       0       0       0
# occupation_ ?                               0       0       0       0       0
# occupation_ Adm-clerical                    0       0       0       1       0
# occupation_ Armed-Forces                    0       0       0       0       0
# occupation_ Craft-repair                    0       0       0       0       0
# occupation_ Exec-managerial                 0       1       0       0       0
# occupation_ Farming-fishing                 0       0       0       0       0
# occupation_ Handlers-cleaners               0       0       0       0       0
# occupation_ Machine-op-inspct               0       0       0       0       0
# occupation_ Other-service                   1       0       0       0       0
# occupation_ Priv-house-serv                 0       0       0       0       0
# occupation_ Prof-specialty                  0       0       1       0       1
# occupation_ Protective-serv                 0       0       0       0       0
# occupation_ Sales                           0       0       0       0       0
# occupation_ Tech-support                    0       0       0       0       0
# occupation_ Transport-moving                0       0       0       0       0
# relationship_ Husband                       1       0       1       0       1
# relationship_ Not-in-family                 0       0       0       0       0
# relationship_ Other-relative                0       0       0       0       0
# relationship_ Own-child                     0       1       0       0       0
# relationship_ Unmarried                     0       0       0       1       0
# relationship_ Wife                          0       0       0       0       0
# race_ Amer-Indian-Eskimo                    0       0       0       0       0
# race_ Asian-Pac-Islander                    0       0       0       0       0
# race_ Black                                 0       0       0       0       0
# race_ Other                                 0       0       0       0       0
# race_ White                                 1       1       1       1       1
# sex_ Female                                 0       0       0       1       0
# sex_ Male                                   1       1       1       0       1
# native-country_Non-US                       0       0       0       0       0
# native-country_United-States                0       1       1       1       0
#
#                                        ...  29065   23346   16840   11863  \
# age                                    ...     28      29      17      22
# fnlwgt                                 ...  33798  144808  108909  110677
# education-num                          ...     11      10       9      10
# capital-gain                           ...      0       0       0       0
# capital-loss                           ...      0       0       0       0
# hours-per-week                         ...     40      40      20      40
# workclass_ ?                           ...      0       0       0       0
# workclass_ Federal-gov                 ...      0       0       0       0
# workclass_ Local-gov                   ...      0       0       0       0
# workclass_ Never-worked                ...      0       0       0       0
# workclass_ Private                     ...      1       1       1       1
# workclass_ Self-emp-inc                ...      0       0       0       0
# workclass_ Self-emp-not-inc            ...      0       0       0       0
# workclass_ State-gov                   ...      0       0       0       0
# workclass_ Without-pay                 ...      0       0       0       0
# education_ 10th                        ...      0       0       0       0
# education_ 11th                        ...      0       0       0       0
# education_ 12th                        ...      0       0       0       0
# education_ 1st-4th                     ...      0       0       0       0
# education_ 5th-6th                     ...      0       0       0       0
# education_ 7th-8th                     ...      0       0       0       0
# education_ 9th                         ...      0       0       0       0
# education_ Assoc-acdm                  ...      0       0       0       0
# education_ Assoc-voc                   ...      1       0       0       0
# education_ Bachelors                   ...      0       0       0       0
# education_ Doctorate                   ...      0       0       0       0
# education_ HS-grad                     ...      0       0       1       0
# education_ Masters                     ...      0       0       0       0
# education_ Preschool                   ...      0       0       0       0
# education_ Prof-school                 ...      0       0       0       0
# education_ Some-college                ...      0       1       0       1
# marital-status_ Divorced               ...      0       0       0       0
# marital-status_ Married-AF-spouse      ...      0       0       0       0
# marital-status_ Married-civ-spouse     ...      1       1       0       0
# marital-status_ Married-spouse-absent  ...      0       0       0       0
# marital-status_ Never-married          ...      0       0       1       0
# marital-status_ Separated              ...      0       0       0       1
# marital-status_ Widowed                ...      0       0       0       0
# occupation_ ?                          ...      0       0       0       0
# occupation_ Adm-clerical               ...      0       0       0       0
# occupation_ Armed-Forces               ...      0       0       0       0
# occupation_ Craft-repair               ...      0       0       0       0
# occupation_ Exec-managerial            ...      0       1       0       0
# occupation_ Farming-fishing            ...      0       0       0       0
# occupation_ Handlers-cleaners          ...      0       0       0       0
# occupation_ Machine-op-inspct          ...      1       0       0       0
# occupation_ Other-service              ...      0       0       0       1
# occupation_ Priv-house-serv            ...      0       0       0       0
# occupation_ Prof-specialty             ...      0       0       0       0
# occupation_ Protective-serv            ...      0       0       0       0
# occupation_ Sales                      ...      0       0       1       0
# occupation_ Tech-support               ...      0       0       0       0
# occupation_ Transport-moving           ...      0       0       0       0
# relationship_ Husband                  ...      1       0       0       0
# relationship_ Not-in-family            ...      0       0       0       0
# relationship_ Other-relative           ...      0       0       0       0
# relationship_ Own-child                ...      0       1       1       1
# relationship_ Unmarried                ...      0       0       0       0
# relationship_ Wife                     ...      0       0       0       0
# race_ Amer-Indian-Eskimo               ...      0       0       0       0
# race_ Asian-Pac-Islander               ...      0       0       0       0
# race_ Black                            ...      0       1       0       0
# race_ Other                            ...      0       0       0       0
# race_ White                            ...      1       0       1       1
# sex_ Female                            ...      0       1       1       1
# sex_ Male                              ...      1       0       0       0
# native-country_Non-US                  ...      0       0       0       1
# native-country_United-States           ...      0       1       1       0
#
#                                         31080   22401   17093   27063   8366   \
# age                                        32      40      36      38      62
# fnlwgt                                 194740  406463  152307  298841  121319
# education-num                              13      14       9       9      13
# capital-gain                                0       0       0       0    3103
# capital-loss                             1902       0       0       0       0
# hours-per-week                             40      40      40      40      40
# workclass_ ?                                0       0       0       0       0
# workclass_ Federal-gov                      0       1       0       0       0
# workclass_ Local-gov                        0       0       0       0       0
# workclass_ Never-worked                     0       0       0       0       0
# workclass_ Private                          1       0       1       1       1
# workclass_ Self-emp-inc                     0       0       0       0       0
# workclass_ Self-emp-not-inc                 0       0       0       0       0
# workclass_ State-gov                        0       0       0       0       0
# workclass_ Without-pay                      0       0       0       0       0
# education_ 10th                             0       0       0       0       0
# education_ 11th                             0       0       0       0       0
# education_ 12th                             0       0       0       0       0
# education_ 1st-4th                          0       0       0       0       0
# education_ 5th-6th                          0       0       0       0       0
# education_ 7th-8th                          0       0       0       0       0
# education_ 9th                              0       0       0       0       0
# education_ Assoc-acdm                       0       0       0       0       0
# education_ Assoc-voc                        0       0       0       0       0
# education_ Bachelors                        1       0       0       0       1
# education_ Doctorate                        0       0       0       0       0
# education_ HS-grad                          0       0       1       1       0
# education_ Masters                          0       1       0       0       0
# education_ Preschool                        0       0       0       0       0
# education_ Prof-school                      0       0       0       0       0
# education_ Some-college                     0       0       0       0       0
# marital-status_ Divorced                    0       0       0       1       0
# marital-status_ Married-AF-spouse           0       0       0       0       0
# marital-status_ Married-civ-spouse          1       0       1       0       1
# marital-status_ Married-spouse-absent       0       0       0       0       0
# marital-status_ Never-married               0       1       0       0       0
# marital-status_ Separated                   0       0       0       0       0
# marital-status_ Widowed                     0       0       0       0       0
# occupation_ ?                               0       0       0       0       0
# occupation_ Adm-clerical                    0       0       0       1       0
# occupation_ Armed-Forces                    0       0       0       0       0
# occupation_ Craft-repair                    0       0       0       0       0
# occupation_ Exec-managerial                 0       0       0       0       0
# occupation_ Farming-fishing                 0       0       0       0       0
# occupation_ Handlers-cleaners               0       0       0       0       0
# occupation_ Machine-op-inspct               0       0       1       0       0
# occupation_ Other-service                   0       0       0       0       0
# occupation_ Priv-house-serv                 0       0       0       0       0
# occupation_ Prof-specialty                  0       0       0       0       1
# occupation_ Protective-serv                 0       0       0       0       0
# occupation_ Sales                           1       0       0       0       0
# occupation_ Tech-support                    0       1       0       0       0
# occupation_ Transport-moving                0       0       0       0       0
# relationship_ Husband                       1       0       1       0       1
# relationship_ Not-in-family                 0       1       0       0       0
# relationship_ Other-relative                0       0       0       0       0
# relationship_ Own-child                     0       0       0       1       0
# relationship_ Unmarried                     0       0       0       0       0
# relationship_ Wife                          0       0       0       0       0
# race_ Amer-Indian-Eskimo                    0       0       0       0       0
# race_ Asian-Pac-Islander                    0       0       0       0       0
# race_ Black                                 0       0       0       0       0
# race_ Other                                 0       0       0       0       0
# race_ White                                 1       1       1       1       1
# sex_ Female                                 0       1       0       1       0
# sex_ Male                                   1       0       1       0       1
# native-country_Non-US                       0       0       0       0       0
# native-country_United-States                0       1       1       0       1
#
#                                         17530
# age                                        38
# fnlwgt                                 220783
# education-num                               9
# capital-gain                                0
# capital-loss                                0
# hours-per-week                             20
# workclass_ ?                                0
# workclass_ Federal-gov                      0
# workclass_ Local-gov                        0
# workclass_ Never-worked                     0
# workclass_ Private                          1
# workclass_ Self-emp-inc                     0
# workclass_ Self-emp-not-inc                 0
# workclass_ State-gov                        0
# workclass_ Without-pay                      0
# education_ 10th                             0
# education_ 11th                             0
# education_ 12th                             0
# education_ 1st-4th                          0
# education_ 5th-6th                          0
# education_ 7th-8th                          0
# education_ 9th                              0
# education_ Assoc-acdm                       0
# education_ Assoc-voc                        0
# education_ Bachelors                        0
# education_ Doctorate                        0
# education_ HS-grad                          1
# education_ Masters                          0
# education_ Preschool                        0
# education_ Prof-school                      0
# education_ Some-college                     0
# marital-status_ Divorced                    1
# marital-status_ Married-AF-spouse           0
# marital-status_ Married-civ-spouse          0
# marital-status_ Married-spouse-absent       0
# marital-status_ Never-married               0
# marital-status_ Separated                   0
# marital-status_ Widowed                     0
# occupation_ ?                               0
# occupation_ Adm-clerical                    0
# occupation_ Armed-Forces                    0
# occupation_ Craft-repair                    0
# occupation_ Exec-managerial                 0
# occupation_ Farming-fishing                 0
# occupation_ Handlers-cleaners               0
# occupation_ Machine-op-inspct               0
# occupation_ Other-service                   1
# occupation_ Priv-house-serv                 0
# occupation_ Prof-specialty                  0
# occupation_ Protective-serv                 0
# occupation_ Sales                           0
# occupation_ Tech-support                    0
# occupation_ Transport-moving                0
# relationship_ Husband                       0
# relationship_ Not-in-family                 1
# relationship_ Other-relative                0
# relationship_ Own-child                     0
# relationship_ Unmarried                     0
# relationship_ Wife                          0
# race_ Amer-Indian-Eskimo                    0
# race_ Asian-Pac-Islander                    0
# race_ Black                                 0
# race_ Other                                 0
# race_ White                                 1
# sex_ Female                                 1
# sex_ Male                                   0
# native-country_Non-US                       0
# native-country_United-States                1
#
# [68 rows x 26048 columns]

# %%
#okay! Looking pretty good - ready to fit our model . . . but first, let's do these tranformations to our test set.

# %%
# recode the native-country column
X_test['native-country'] = pd.Series(['United-States' if x==' United-States' else 'Non-US' for x in X_test['native-country']])
# one hot encode the cats
X_test_dummied = pd.get_dummies(X_test, columns=cat_vars)

# %%
y_train_numeric = y_train.replace({' <=50K': 0, ' >50K': 1})
y_test_numeric = y_test.replace({' <=50K': 0, ' >50K': 1})

# %%
log_reg = LogisticRegression(random_state=4)

# %%
log_reg.fit(X_train_dummied, y_train_numeric)
# Out:
# LogisticRegression(random_state=4)

# %%
preds = log_reg.predict_proba(X_test_dummied)

# %%
roc_auc_score(y_test_numeric, preds[:,1])
# Out:
# 0.5688196535250225

# %%
print(preds[:,1])
print(preds)
# Out:
# [0.15820743 0.09795604 0.48448576 ... 0.31955798 0.25575679 0.22046736]
# [[0.84179257 0.15820743]
#  [0.90204396 0.09795604]
#  [0.51551424 0.48448576]
#  ...
#  [0.68044202 0.31955798]
#  [0.74424321 0.25575679]
#  [0.77953264 0.22046736]]

# %%
RocCurveDisplay.from_predictions(
    y_test_numeric,
    preds[:, 1],
    name='ROC Curve',
    color="darkorange",
)
plt.plot([0, 1], [0, 1], "k--", label="chance level (AUC = 0.5)")
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
confusion_matrix(y_test_numeric, pd.Series([1 if x > 0.7 else 0 for x in preds[:,1]]))
# Out:
# array([[4946,   26],
#        [1267,  274]])

# %% [markdown]
# Not a great model! It does seem to be maybe useful if you need a (mostly) reliable way to identify a small persentage of high earners (<= 30%).
